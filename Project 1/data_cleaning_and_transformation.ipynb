# %%
# Import Packages
import pandas as pd

# %%
# Reading the CSV
df = pd.read_csv('dataset/Cleaned_DS_Jobs.csv')

# Show the first 5 rows of df
df.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist        137-171
# 1     Data Scientist        137-171
# 2     Data Scientist        137-171
# 3     Data Scientist        137-171
# 4     Data Scientist        137-171
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
#                       Size        Type of ownership  \
# 0   1001 to 5000 employees   Nonprofit Organization
# 1  5001 to 10000 employees         Company - Public
# 2   1001 to 5000 employees  Private Practice / Firm
# 3    501 to 1000 employees         Company - Public
# 4      51 to 200 employees        Company - Private
#
#                                 Industry  ... company_age python  excel  \
# 0                     Insurance Carriers  ...          27      0      0
# 1                 Research & Development  ...          52      0      0
# 2                             Consulting  ...          39      1      1
# 3  Electrical & Electronic Manufacturing  ...          20      1      1
# 4                Advertising & Marketing  ...          22      1      1
#
#    hadoop  spark aws  tableau  big_data        job_simp  seniority
# 0       0      0   1        0         0  data scientist     senior
# 1       1      0   0        0         1  data scientist         na
# 2       0      0   1        0         0  data scientist         na
# 3       0      0   1        0         0  data scientist         na
# 4       0      0   0        0         0  data scientist         na
#
# [5 rows x 27 columns]

# %% [markdown]
# 1. Make the 'Salary Estimate' column into floats

# %%
def calculate_average_from_range(range) -> float:
    #range example: "100-120"
    lower, upper = map(int, range.split("-"))
    average = (upper + lower) / 2
    return average

df['Salary Estimate'] = df['Salary Estimate'].apply(lambda x: calculate_average_from_range(x))
df.head()
# Out:
#            Job Title  Salary Estimate  \
# 0  Sr Data Scientist            154.0
# 1     Data Scientist            154.0
# 2     Data Scientist            154.0
# 3     Data Scientist            154.0
# 4     Data Scientist            154.0
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#          Company Name       Location            Headquarters  \
# 0         Healthfirst   New York, NY            New York, NY
# 1             ManTech  Chantilly, VA             Herndon, VA
# 2      Analysis Group     Boston, MA              Boston, MA
# 3             INFICON     Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions   New York, NY            New York, NY
#
#                       Size        Type of ownership  \
# 0   1001 to 5000 employees   Nonprofit Organization
# 1  5001 to 10000 employees         Company - Public
# 2   1001 to 5000 employees  Private Practice / Firm
# 3    501 to 1000 employees         Company - Public
# 4      51 to 200 employees        Company - Private
#
#                                 Industry  ... company_age python  excel  \
# 0                     Insurance Carriers  ...          27      0      0
# 1                 Research & Development  ...          52      0      0
# 2                             Consulting  ...          39      1      1
# 3  Electrical & Electronic Manufacturing  ...          20      1      1
# 4                Advertising & Marketing  ...          22      1      1
#
#    hadoop  spark aws  tableau  big_data        job_simp  seniority
# 0       0      0   1        0         0  data scientist     senior
# 1       1      0   0        0         1  data scientist         na
# 2       0      0   1        0         0  data scientist         na
# 3       0      0   1        0         0  data scientist         na
# 4       0      0   0        0         0  data scientist         na
#
# [5 rows x 27 columns]

# %% [markdown]
# 2. Delete everthing after ',' in column "Headquarters" and "Location"

# %%
df['Headquarters'] = df['Headquarters'].apply(lambda x: x.split(',')[0])
df['Location'] = df['Location'].apply(lambda x: x.split(',')[0])
df[['Headquarters', 'Location']]
# Out:
#              Headquarters             Location
# 0                New York             New York
# 1                 Herndon            Chantilly
# 2                  Boston               Boston
# 3               Bad Ragaz               Newton
# 4                New York             New York
# 5           Santa Barbara        Santa Barbara
# 6                   Basel            Cambridge
# 7                 Bedford              Bedford
# 8           Mountain View            San Diego
# 9                 Chicago              Chicago
# 10                Mc Lean              Herndon
# 11            Saint Louis          Saint Louis
# 12               Richland             Richland
# 13             Northbrook           Northbrook
# 14              Princeton           Washington
# 15           Mays Landing           Washington
# 16                Memphis              Memphis
# 17                  Tempe                Plano
# 18                Reading           West Grove
# 19          San Francisco             New York
# 20               New York             New York
# 21             Menlo Park              Phoenix
# 22               New York             Appleton
# 23                Chicago              Chicago
# 24                Atlanta              Atlanta
# 25                Orlando              Orlando
# 26              Lexington            Lexington
# 27           Falls Church               McLean
# 28          San Francisco        San Francisco
# 29                 Boston               Boston
# 30                  Basel            Cambridge
# 31                 Boston               Boston
# 32              Sheboygan            Sheboygan
# 33                Seattle        United States
# 34               Bellevue              Bothell
# 35                Lincoln              Lincoln
# 36               New York        Overland Park
# 37              Chantilly            Chantilly
# 38           Santa Monica         Santa Monica
# 39                 Boston               Boston
# 40                 Boston           Portsmouth
# 41                  Ewing                Ewing
# 42    South San Francisco  South San Francisco
# 43              Palo Alto            Palo Alto
# 44               New York            Cambridge
# 45                 Boston               Boston
# 46               Bellevue             Bellevue
# 47              Singapore        San Francisco
# 48              Cambridge            Cambridge
# 49          San Francisco        San Francisco
# 50                  OSAKA            Cambridge
# 51            Santa Clara        San Francisco
# 52            New Orleans          New Orleans
# 53                  Akron                Akron
# 54            Saint Louis          Saint Louis
# 55          San Francisco        San Francisco
# 56          San Francisco        San Francisco
# 57            Saint Louis          Saint Louis
# 58                 Zurich           Fort Wayne
# 59                 Woburn               Woburn
# 60                Bedford              Bedford
# 61          Santa Barbara        Santa Barbara
# 62                 Carson               Carson
# 63           Coral Gables         Coral Gables
# 64               New York             New York
# 65              San Ramon          Santa Clara
# 66                Chicago              Chicago
# 67               Brisbane             Brisbane
# 68            Winter Park          Winter Park
# 69                Chicago         Redwood City
# 70             San Rafael        San Francisco
# 71              Deerfield               Peoria
# 72                Ipswich              Ipswich
# 73                 Carmel               Carmel
# 74               New York             New York
# 75            Chevy Chase           Washington
# 76               Hartford             New York
# 77             Emeryville           Emeryville
# 78              Cambridge         Gaithersburg
# 79              Rockville           Washington
# 80            Minneapolis          Saint Louis
# 81                Chicago             Longmont
# 82                 Austin               Austin
# 83          San Francisco        San Francisco
# 84                 Yakima               Yakima
# 85             Santa Cruz           Santa Cruz
# 86                 Boston               Boston
# 87                Mc Lean        United States
# 88              Cambridge         Gaithersburg
# 89                Mc Lean          Springfield
# 90                Herndon           Alexandria
# 91              Princeton           Washington
# 92          Mountain View            San Diego
# 93                 Reston               Reston
# 94                Mc Lean             New York
# 95                 Denver               Denver
# 96             Washington           Washington
# 97                 Aurora               Aurora
# 98              San Mateo        Santa Barbara
# 99             San Rafael        San Francisco
# 100         Mountain View            San Diego
# 101                Goleta             Hill AFB
# 102              Franklin             Chandler
# 103          Indianapolis         Indianapolis
# 104             Palo Alto            San Diego
# 105                Reston            Chantilly
# 106              New York            Nashville
# 107  Lutherville Timonium             Timonium
# 108           Westminster              Herndon
# 109            Burlingame           Burlingame
# 110                Reston               Reston
# 111              New York             New York
# 112    Annapolis Junction   Annapolis Junction
# 113              New York            Nashville
# 114   South San Francisco  South San Francisco
# 115              Bethesda             Bethesda
# 116           Beavercreek               Dayton
# 117         San Francisco        San Francisco
# 118               Mc Lean              Herndon
# 119           Winter Park          Winter Park
# 120            Schaumburg           Schaumburg
# 121             Sunnyvale            Cupertino
# 122           Saint Louis          Saint Louis
# 123               Chicago              Chicago
# 124           Winter Park          Winter Park
# 125             Sunnyvale            Cupertino
# 126         San Francisco        San Francisco
# 127                  Lehi                 Lehi
# 128              New York          Culver City
# 129           Lake Oswego          Lake Oswego
# 130                  Lehi                 Lehi
# 131             San Mateo            San Mateo
# 132           Saint Louis        San Francisco
# 133             Palo Alto            Palo Alto
# 134               Holyoke              Holyoke
# 135               Chicago              Chicago
# 136         San Francisco        San Francisco
# 137               Bedford               McLean
# 138                Dulles              Herndon
# 139              Bethesda             Bethesda
# 140                Boston           Woodbridge
# 141             San Diego            San Diego
# 142             Cambridge            Cambridge
# 143               Detroit             Dearborn
# 144              Stamford     Maryland Heights
# 145             Rockville            Rockville
# 146           Carpinteria          Carpinteria
# 147              Columbia             Columbia
# 148                    -1            Hauppauge
# 149        Marcy-l'Etoile          Saint Louis
# 150               Mc Lean              Herndon
# 151          Mays Landing           Washington
# 152                    -1               Reston
# 153                Reston           Fort Meade
# 154         San Francisco        San Francisco
# 155              Columbia             Columbia
# 156           Westminster            Chantilly
# 157            Washington           Washington
# 158               Fairfax            Vicksburg
# 159              Chandler             Chandler
# 160            San Rafael        San Francisco
# 161               Herndon        San Francisco
# 162                Aurora           Birmingham
# 163             Blue Bell            Blue Bell
# 164                  Troy              Chicago
# 165               Chicago         Redwood City
# 166          Redwood City         Redwood City
# 167              New York             New York
# 168             San Diego            San Diego
# 169               Chicago              Chicago
# 170            Greenville           Cincinnati
# 171              Richland             Richland
# 172               Memphis              Memphis
# 173             Arlington              Memphis
# 174              Bethesda             Bethesda
# 175            Harrisburg           Harrisburg
# 176              Hamilton             New York
# 177             Lynchburg            Oak Ridge
# 178         San Francisco        San Francisco
# 179           Springfield               Boston
# 180            San Carlos           San Carlos
# 181   South San Francisco  South San Francisco
# 182               Herndon              Herndon
# 183               Waltham              Waltham
# 184              San Jose        San Francisco
# 185         Mountain View          Santa Clara
# 186             Cambridge         Gaithersburg
# 187           Jersey City        San Francisco
# 188             Cambridge             New York
# 189            Santa Cruz           San Carlos
# 190            Fort Worth           Fort Worth
# 191             Cambridge           Smithfield
# 192          Cedar Rapids         Cedar Rapids
# 193               Chicago              Chicago
# 194                McLean               McLean
# 195                Lorton         Fort Belvoir
# 196         San Francisco        San Francisco
# 197                 Basel            Cambridge
# 198               Mc Lean    Linthicum Heights
# 199               Mc Lean              Herndon
# 200           Maple Plain          Maple Plain
# 201                  Kent                Tulsa
# 202              Woodbine   Annapolis Junction
# 203                Denver               Newton
# 204           Westminster              Herndon
# 205              Woodbine            Baltimore
# 206                Boston               Boston
# 207           San Antonio        Oklahoma City
# 208             Cambridge         Gaithersburg
# 209                Reston         Fort Belvoir
# 210         Scotts Valley        Scotts Valley
# 211           Springfield               Boston
# 212               Chicago         Redwood City
# 213           Spartanburg          Spartanburg
# 214              New York             New York
# 215               Orlando              Orlando
# 216            Greenville           Cincinnati
# 217         San Francisco        San Francisco
# 218            Woodbridge             Hartford
# 219               Chennai              Chicago
# 220         Tel Aviv-Yafo        United States
# 221             Arlington          Beavercreek
# 222             Baltimore            Baltimore
# 223             Manalapan              Norfolk
# 224              Bethesda             Bethesda
# 225             Lynchburg            Oak Ridge
# 226             Charlotte            Charlotte
# 227              Hamilton             New York
# 228             Saxonburg            Champaign
# 229               Bristol        San Francisco
# 230         San Francisco        San Francisco
# 231             Bangalore                Plano
# 232               Atlanta              Atlanta
# 233             Sheboygan            Sheboygan
# 234              New York             New York
# 235         Mountain View            Palo Alto
# 236               Hoboken              Hoboken
# 237                 Paris            Cambridge
# 238             Greenwich              Lebanon
# 239             Santa Ana              Oakland
# 240               Houston        San Francisco
# 241                Tucson            Melbourne
# 242           Springfield               Boston
# 243            Birmingham           Birmingham
# 244             Cleveland            Cleveland
# 245            Washington             New York
# 246              New York             New York
# 247            Pleasanton        San Francisco
# 248              Columbus              Norwell
# 249               Herndon              Herndon
# 250                    -1             New York
# 251              New York             San Jose
# 252              San Jose        San Francisco
# 253               Waltham              Waltham
# 254             Lexington            Lexington
# 255              Bellevue              Bothell
# 256              Richland             Richland
# 257                Boston               Boston
# 258             Rockville            Rockville
# 259            Piscataway           Piscataway
# 260              San Jose             San Jose
# 261              New York             New York
# 262         Mountain View          Santa Clara
# 263               Danvers              Danvers
# 264          Philadelphia             New York
# 265               Fairfax               Vienna
# 266           Jersey City        San Francisco
# 267             Livermore            Livermore
# 268            Pittsburgh           Pittsburgh
# 269                Dallas              Herndon
# 270                Boston               Boston
# 271            Northbrook           Northbrook
# 272               Toronto               Irvine
# 273                Irvine               Irvine
# 274          Hillsborough        San Francisco
# 275          Santa Monica         Santa Monica
# 276                Boston               Boston
# 277          Hillsborough        San Francisco
# 278             Cambridge             New York
# 279               Oshkosh              Oshkosh
# 280            Santa Cruz           San Carlos
# 281            Pittsburgh           Menlo Park
# 282               Fremont        San Francisco
# 283          Hillsborough               Dallas
# 284                Reston            Arlington
# 285              New York        San Francisco
# 286                Monroe               Monroe
# 287              Goteborg           Sacramento
# 288              New York             New York
# 289            Washington               Reston
# 290      Lake Buena Vista             New York
# 291          Schaffhausen              Hampton
# 292              Richmond             Richmond
# 293                Newark             New York
# 294            Greensboro             Monterey
# 295         San Francisco              Chicago
# 296          Falls Church               McLean
# 297             Rockville             Woodlawn
# 298            Scottsdale        United States
# 299                Irving             New York
# 300            Beltsville               Reston
# 301               Houston             New York
# 302            Fort Worth           Fort Worth
# 303             Cambridge           Smithfield
# 304               Toronto              Atlanta
# 305         San Francisco        San Francisco
# 306                 Paris            Ann Arbor
# 307            Pittsburgh           Pittsburgh
# 308            Naperville             New York
# 309          Cedar Rapids         Cedar Rapids
# 310             Princeton             New York
# 311               Memphis              Concord
# 312             Brentford             Richmond
# 313            Cincinnati           Cincinnati
# 314             Singapore        San Francisco
# 315              Bellevue             Bellevue
# 316         San Francisco        San Francisco
# 317              Somerset              Oakland
# 318                London        San Francisco
# 319               Raleigh               Boston
# 320              Leesburg               Reston
# 321                Lorton         Fort Belvoir
# 322                Durham               Durham
# 323              New York             New York
# 324    Annapolis Junction               McLean
# 325                 Basel            Cambridge
# 326               Chicago              Chicago
# 327                  Kent                 Kent
# 328             Chantilly               Reston
# 329      Westlake Village        San Francisco
# 330            Pittsburgh           Pittsburgh
# 331                Carson               Carson
# 332       North Brunswick             New York
# 333              New York             New York
# 334           Santa Clara          Santa Clara
# 335             Palo Alto            Palo Alto
# 336           Maple Plain          Maple Plain
# 337               Lincoln           Cincinnati
# 338              San Jose             San Jose
# 339               Benicia          Santa Clara
# 340              New York             New York
# 341    Annapolis Junction            Chantilly
# 342                    -1            Palo Alto
# 343                Laurel               Laurel
# 344             Cambridge            Cambridge
# 345              Columbia             Columbia
# 346              Woodbine   Annapolis Junction
# 347                Vienna         Falls Church
# 348                    -1        San Francisco
# 349                    -1        San Francisco
# 350                    -1        San Francisco
# 351                    -1        San Francisco
# 352                    -1        San Francisco
# 353                    -1        San Francisco
# 354           Westminster              Herndon
# 355             Cambridge            Cambridge
# 356                 OSAKA            Cambridge
# 357           Westminster              Herndon
# 358           San Antonio        Oklahoma City
# 359              Danville        Thousand Oaks
# 360                Boston               Boston
# 361             Cambridge         Gaithersburg
# 362            Wilmington               Edison
# 363             Chantilly              Adelphi
# 364              New York           Washington
# 365               Seattle              Seattle
# 366               Reading                Plano
# 367            Pleasanton            Sunnyvale
# 368                Denver               Denver
# 369                Folsom        Thousand Oaks
# 370               Raleigh               McLean
# 371         Scotts Valley        Scotts Valley
# 372           Springfield               Boston
# 373                Austin               Boston
# 374              Hartford             Hartford
# 375         San Francisco        San Francisco
# 376                Boston               Boston
# 377                Denver               Denver
# 378             Cambridge            Cambridge
# 379                    -1        San Francisco
# 380                    -1        San Francisco
# 381               Chicago         Redwood City
# 382           Wilsonville              Fremont
# 383             Princeton             Hamilton
# 384          Falls Church         Falls Church
# 385               Chicago              Chicago
# 386                Boston         Indianapolis
# 387                Folsom           Washington
# 388           Westminster              Herndon
# 389            Huntsville           Huntsville
# 390                Woburn               Woburn
# 391               Mc Lean              Herndon
# 392                Vienna           Merrifield
# 393               Madison              Madison
# 394                 Phila         Philadelphia
# 395         Winston-Salem        Winston-Salem
# 396          Indianapolis              Raleigh
# 397         San Francisco        San Francisco
# 398         San Francisco        San Francisco
# 399              Columbia             Columbia
# 400         Half Moon Bay            San Mateo
# 401                Boston               Boston
# 402           Los Angeles              Burbank
# 403                London            Sunnyvale
# 404              Hilliard            San Ramon
# 405               Hanover           Washington
# 406             Arlington          Springfield
# 407                Irvine              Phoenix
# 408               Mc Lean               Oxnard
# 409           Kansas City          Kansas City
# 410             Bengaluru          Jersey City
# 411            Menlo Park           Manchester
# 412          Cedar Rapids         Cedar Rapids
# 413            Alpharetta              Winters
# 414                 Paris            Ann Arbor
# 415                    -1             Brooklyn
# 416             Princeton             New York
# 417                McLean               McLean
# 418              New York             New York
# 419           Saint Louis          Saint Louis
# 420               Memphis              Concord
# 421            Washington         Fort Belvoir
# 422            Cincinnati           Cincinnati
# 423         San Francisco        San Francisco
# 424            Germantown           Germantown
# 425                 Omaha                Omaha
# 426                Reston               McLean
# 427          Clifton Park            Open Fork
# 428              Leesburg               Reston
# 429               Livonia        United States
# 430            San Carlos           San Carlos
# 431                Boston               Boston
# 432               Ashburn              Ashburn
# 433             Nashville              Lombard
# 434            Alexandria              Hampton
# 435           Los Angeles        San Francisco
# 436              New York             New York
# 437           Saint Louis          Saint Louis
# 438            San Rafael        San Francisco
# 439                Edison               Edison
# 440                 Basel            Cambridge
# 441              Somerset           Alpharetta
# 442               Ventura              Boulder
# 443                Armonk              Atlanta
# 444               Fairfax         Falls Church
# 445              San Jose        Mountain View
# 446                  Kent                 Kent
# 447              Trumbull             Trumbull
# 448      Westlake Village        San Francisco
# 449            Pittsburgh           Pittsburgh
# 450                    -1             Sterling
# 451              New York             New York
# 452           Minneapolis           Alpharetta
# 453           Chadds Ford         Philadelphia
# 454                Carson               Carson
# 455                Edison          Foster City
# 456       North Brunswick             New York
# 457               Chicago            Frederick
# 458               Chicago              Chicago
# 459             San Ramon          Santa Clara
# 460              New York             New York
# 461           Maple Plain          Maple Plain
# 462           Los Angeles     Colorado Springs
# 463              San Jose             San Jose
# 464              Stamford        United States
# 465               Lincoln           Cincinnati
# 466               Atlanta              Atlanta
# 467              New York           Washington
# 468             Arlington            Arlington
# 469           Santa Clara          Santa Clara
# 470                  Kent                Tulsa
# 471    Annapolis Junction            Chantilly
# 472            Saint Paul           Southfield
# 473            Glen Allen        San Francisco
# 474                Reston        United States
# 475                Laurel               Laurel
# 476             Cambridge            Cambridge
# 477              Woodbine   Annapolis Junction
# 478               Chicago         Redwood City
# 479           Chevy Chase           Washington
# 480           Aliso Viejo         San Clemente
# 481            Plainsboro             New York
# 482                Vienna         Falls Church
# 483                Denver               Newton
# 484         San Francisco        San Francisco
# 485              Fairmont           Washington
# 486                    -1        San Francisco
# 487                    -1        San Francisco
# 488                    -1        San Francisco
# 489                    -1        San Francisco
# 490                    -1        San Francisco
# 491                    -1        San Francisco
# 492               Houston        The Woodlands
# 493           Jersey City              Seattle
# 494           Cherry Hill              Chicago
# 495                    -1            Chantilly
# 496                Itasca              Chicago
# 497         San Francisco        San Francisco
# 498              Woodbine            Baltimore
# 499                 Basel           Pleasanton
# 500             Cambridge           Wilmington
# 501           Los Angeles        United States
# 502         Coconut Creek             New York
# 503           Westminster              Herndon
# 504               Lombard              Seattle
# 505           Westminster              Herndon
# 506              Honolulu     Fort Sam Houston
# 507           San Antonio        Oklahoma City
# 508             Chantilly       Lexington Park
# 509                Boston               Boston
# 510                    -1            Cambridge
# 511              Columbus           Washington
# 512             Arlington           Washington
# 513            Pleasanton              Raleigh
# 514           San Antonio               Dayton
# 515              New York             New York
# 516              New York           Washington
# 517               Seattle              Seattle
# 518           Carle Place             New York
# 519            Alexandria           Washington
# 520               Chicago             Longmont
# 521             Rockville           Washington
# 522            Germantown           Washington
# 523            Pleasanton            Sunnyvale
# 524         San Francisco        San Francisco
# 525               Orlando             Patuxent
# 526             Cupertino          Santa Clara
# 527                 Tampa              Fairfax
# 528                Denver               Denver
# 529                Reston         Fort Belvoir
# 530               Chicago              Chicago
# 531                Folsom        Thousand Oaks
# 532               Raleigh               McLean
# 533           San Antonio          San Antonio
# 534                Reston        Silver Spring
# 535           Springfield               Boston
# 536                Reston           Washington
# 537                Totowa             New York
# 538          Cedar Rapids               McLean
# 539              Hartford             Hartford
# 540            Emeryville           Emeryville
# 541                Austin               Austin
# 542         San Francisco        San Francisco
# 543         San Francisco        San Francisco
# 544         San Francisco             Portland
# 545             Cambridge            Cambridge
# 546                    -1        San Francisco
# 547               Chicago         Redwood City
# 548             San Diego            San Diego
# 549                  Rome             New York
# 550                McLean            Chantilly
# 551          Falls Church         Falls Church
# 552               Herndon            Chantilly
# 553                 Milan              Chicago
# 554            San Rafael        San Francisco
# 555               Chicago              Chicago
# 556               Raleigh              Raleigh
# 557               Orlando              Orlando
# 558              New York             New York
# 559              Marbella         Philadelphia
# 560               Bedford               McLean
# 561               Mc Lean        United States
# 562            Santa Cruz           Santa Cruz
# 563           Simi Valley          Simi Valley
# 564           Westminster              Herndon
# 565            Huntsville           Huntsville
# 566                Woburn               Woburn
# 567               Mc Lean              Herndon
# 568                Austin               Austin
# 569                Vienna           Merrifield
# 570               Bedford          New Bedford
# 571   South San Francisco  South San Francisco
# 572                Vienna           Merrifield
# 573         Winston-Salem        Winston-Salem
# 574               Bedford              Bedford
# 575          Indianapolis              Raleigh
# 576               Bedford          New Bedford
# 577               Chicago              Chicago
# 578      Rancho Cucamonga     Rancho Cucamonga
# 579              New York             New York
# 580           Albuquerque            Livermore
# 581           Westminster               McLean
# 582             Cambridge         Gaithersburg
# 583            San Rafael        San Francisco
# 584            Saint Paul           Southfield
# 585             Brentford         Collegeville
# 586               Langley           Washington
# 587               Chicago              Chicago
# 588           Minneapolis          Minneapolis
# 589              New York              Gahanna
# 590             Nashville            Nashville
# 591                Reston        United States
# 592                Laurel               Laurel
# 593              Woodbine   Annapolis Junction
# 594           Aliso Viejo         San Clemente
# 595            Plainsboro             New York
# 596                Reston           Washington
# 597           Aliso Viejo              Atlanta
# 598                 Plano                Plano
# 599               Fairfax              Fairfax
# 600              Fairmont           Washington
# 601               Herndon           Alexandria
# 602                    -1                Omaha
# 603              Bethesda            Wellesley
# 604                McLean           Washington
# 605           Albertville           Fort Worth
# 606           Aliso Viejo              Atlanta
# 607               Fairfax           Alexandria
# 608              Bellevue             Bellevue
# 609             San Diego        United States
# 610      Westlake Village        Thousand Oaks
# 611                Orange               Orange
# 612              New York            Baltimore
# 613             Littleton              Herndon
# 614            Alexandria           Alexandria
# 615                Reston           Bridgeport
# 616               Houston        The Woodlands
# 617              Oakville             Oakville
# 618                Itasca              Chicago
# 619                Vienna            Arlington
# 620               Mc Lean             New York
# 621               Fremont              Seattle
# 622            Naperville           Naperville
# 623         San Francisco        San Francisco
# 624              Woodbine            Baltimore
# 625                    -1            Chantilly
# 626           Westminster              Herndon
# 627             San Bruno             Bellevue
# 628         Coconut Creek             New York
# 629            Naperville              Chicago
# 630           Kansas City          Kansas City
# 631               Houston              Houston
# 632             Arlington            Chantilly
# 633             Cupertino          Santa Clara
# 634           Westminster              Herndon
# 635           San Antonio        Oklahoma City
# 636              Danville        Thousand Oaks
# 637                Boston               Boston
# 638                    -1            Cambridge
# 639             Cambridge         Gaithersburg
# 640                Denver               Denver
# 641             Sunnyvale            Cupertino
# 642             Chantilly       Lexington Park
# 643              Columbus           Washington
# 644                    -1         Fort Belvoir
# 645                    -1           Naperville
# 646             Arlington           Washington
# 647             Chantilly              Adelphi
# 648                    -1              Redmond
# 649          West Chester         West Chester
# 650            Wilmington               Edison
# 651                 Utica               Durham
# 652             Baltimore             Quantico
# 653                Vienna               Vienna
# 654             Cambridge               Boston
# 655              Fort Lee             Fort Lee
# 656                    -1        San Francisco
# 657                    -1            Irwindale
# 658           Santa Clara        San Francisco
# 659           Carle Place             New York

# %% [markdown]
# 3. Create new column with average 'Size'

# %%
def calculate_average_size(x):
    parts = x.split(" ")
    if len(parts) > 3:
        a = parts[0]
        b = parts[2]
        a = int(a)
        b = int(b)
        average = (a+b) / 2
        return average
    else:
        return x
    
    
df['Average Size'] = df['Size'].apply(lambda x: calculate_average_size(x))
df[['Size', 'Average Size']]
# Out:
#                         Size      Average Size
# 0     1001 to 5000 employees            3000.5
# 1    5001 to 10000 employees            7500.5
# 2     1001 to 5000 employees            3000.5
# 3      501 to 1000 employees             750.5
# 4        51 to 200 employees             125.5
# 5        51 to 200 employees             125.5
# 6           10000+ employees  10000+ employees
# 7     1001 to 5000 employees            3000.5
# 8    5001 to 10000 employees            7500.5
# 9        51 to 200 employees             125.5
# 10     501 to 1000 employees             750.5
# 11       51 to 200 employees             125.5
# 12    1001 to 5000 employees            3000.5
# 13      201 to 500 employees             350.5
# 14    1001 to 5000 employees            3000.5
# 15         1 to 50 employees              25.5
# 16    1001 to 5000 employees            3000.5
# 17   5001 to 10000 employees            7500.5
# 18   5001 to 10000 employees            7500.5
# 19       51 to 200 employees             125.5
# 20       51 to 200 employees             125.5
# 21    1001 to 5000 employees            3000.5
# 22   5001 to 10000 employees            7500.5
# 23       51 to 200 employees             125.5
# 24       51 to 200 employees             125.5
# 25       51 to 200 employees             125.5
# 26    1001 to 5000 employees            3000.5
# 27       51 to 200 employees             125.5
# 28       51 to 200 employees             125.5
# 29    1001 to 5000 employees            3000.5
# 30          10000+ employees  10000+ employees
# 31         1 to 50 employees              25.5
# 32    1001 to 5000 employees            3000.5
# 33      201 to 500 employees             350.5
# 34    1001 to 5000 employees            3000.5
# 35    1001 to 5000 employees            3000.5
# 36     501 to 1000 employees             750.5
# 37         1 to 50 employees              25.5
# 38     501 to 1000 employees             750.5
# 39     501 to 1000 employees             750.5
# 40          10000+ employees  10000+ employees
# 41    1001 to 5000 employees            3000.5
# 42       51 to 200 employees             125.5
# 43       51 to 200 employees             125.5
# 44          10000+ employees  10000+ employees
# 45      201 to 500 employees             350.5
# 46     501 to 1000 employees             750.5
# 47    1001 to 5000 employees            3000.5
# 48      201 to 500 employees             350.5
# 49         1 to 50 employees              25.5
# 50          10000+ employees  10000+ employees
# 51     501 to 1000 employees             750.5
# 52       51 to 200 employees             125.5
# 53   5001 to 10000 employees            7500.5
# 54      201 to 500 employees             350.5
# 55    1001 to 5000 employees            3000.5
# 56    1001 to 5000 employees            3000.5
# 57      201 to 500 employees             350.5
# 58          10000+ employees  10000+ employees
# 59      201 to 500 employees             350.5
# 60    1001 to 5000 employees            3000.5
# 61       51 to 200 employees             125.5
# 62      201 to 500 employees             350.5
# 63    1001 to 5000 employees            3000.5
# 64     501 to 1000 employees             750.5
# 65    1001 to 5000 employees            3000.5
# 66     501 to 1000 employees             750.5
# 67         1 to 50 employees              25.5
# 68       51 to 200 employees             125.5
# 69     501 to 1000 employees             750.5
# 70   5001 to 10000 employees            7500.5
# 71          10000+ employees  10000+ employees
# 72      201 to 500 employees             350.5
# 73    1001 to 5000 employees            3000.5
# 74    1001 to 5000 employees            3000.5
# 75    1001 to 5000 employees            3000.5
# 76      201 to 500 employees             350.5
# 77      201 to 500 employees             350.5
# 78          10000+ employees  10000+ employees
# 79       51 to 200 employees             125.5
# 80       51 to 200 employees             125.5
# 81         1 to 50 employees              25.5
# 82       51 to 200 employees             125.5
# 83    1001 to 5000 employees            3000.5
# 84     501 to 1000 employees             750.5
# 85       51 to 200 employees             125.5
# 86      201 to 500 employees             350.5
# 87          10000+ employees  10000+ employees
# 88          10000+ employees  10000+ employees
# 89       51 to 200 employees             125.5
# 90   5001 to 10000 employees            7500.5
# 91    1001 to 5000 employees            3000.5
# 92   5001 to 10000 employees            7500.5
# 93       51 to 200 employees             125.5
# 94          10000+ employees  10000+ employees
# 95       51 to 200 employees             125.5
# 96    1001 to 5000 employees            3000.5
# 97         1 to 50 employees              25.5
# 98       51 to 200 employees             125.5
# 99   5001 to 10000 employees            7500.5
# 100  5001 to 10000 employees            7500.5
# 101    501 to 1000 employees             750.5
# 102    501 to 1000 employees             750.5
# 103      51 to 200 employees             125.5
# 104         10000+ employees  10000+ employees
# 105         10000+ employees  10000+ employees
# 106   1001 to 5000 employees            3000.5
# 107      51 to 200 employees             125.5
# 108  5001 to 10000 employees            7500.5
# 109        1 to 50 employees              25.5
# 110   1001 to 5000 employees            3000.5
# 111        1 to 50 employees              25.5
# 112      51 to 200 employees             125.5
# 113   1001 to 5000 employees            3000.5
# 114      51 to 200 employees             125.5
# 115     201 to 500 employees             350.5
# 116      51 to 200 employees             125.5
# 117      51 to 200 employees             125.5
# 118    501 to 1000 employees             750.5
# 119      51 to 200 employees             125.5
# 120      51 to 200 employees             125.5
# 121  5001 to 10000 employees            7500.5
# 122      51 to 200 employees             125.5
# 123      51 to 200 employees             125.5
# 124      51 to 200 employees             125.5
# 125  5001 to 10000 employees            7500.5
# 126        1 to 50 employees              25.5
# 127     201 to 500 employees             350.5
# 128      51 to 200 employees             125.5
# 129   1001 to 5000 employees            3000.5
# 130     201 to 500 employees             350.5
# 131     201 to 500 employees             350.5
# 132     201 to 500 employees             350.5
# 133     201 to 500 employees             350.5
# 134    501 to 1000 employees             750.5
# 135   1001 to 5000 employees            3000.5
# 136      51 to 200 employees             125.5
# 137  5001 to 10000 employees            7500.5
# 138        1 to 50 employees              25.5
# 139    501 to 1000 employees             750.5
# 140   1001 to 5000 employees            3000.5
# 141    501 to 1000 employees             750.5
# 142      51 to 200 employees             125.5
# 143     201 to 500 employees             350.5
# 144         10000+ employees  10000+ employees
# 145     201 to 500 employees             350.5
# 146   1001 to 5000 employees            3000.5
# 147     201 to 500 employees             350.5
# 148                       -1                -1
# 149         10000+ employees  10000+ employees
# 150    501 to 1000 employees             750.5
# 151        1 to 50 employees              25.5
# 152                       -1                -1
# 153         10000+ employees  10000+ employees
# 154     201 to 500 employees             350.5
# 155   1001 to 5000 employees            3000.5
# 156  5001 to 10000 employees            7500.5
# 157    501 to 1000 employees             750.5
# 158         10000+ employees  10000+ employees
# 159     201 to 500 employees             350.5
# 160  5001 to 10000 employees            7500.5
# 161  5001 to 10000 employees            7500.5
# 162         10000+ employees  10000+ employees
# 163   1001 to 5000 employees            3000.5
# 164  5001 to 10000 employees            7500.5
# 165    501 to 1000 employees             750.5
# 166     201 to 500 employees             350.5
# 167     201 to 500 employees             350.5
# 168   1001 to 5000 employees            3000.5
# 169    501 to 1000 employees             750.5
# 170     201 to 500 employees             350.5
# 171   1001 to 5000 employees            3000.5
# 172   1001 to 5000 employees            3000.5
# 173    501 to 1000 employees             750.5
# 174    501 to 1000 employees             750.5
# 175     201 to 500 employees             350.5
# 176   1001 to 5000 employees            3000.5
# 177  5001 to 10000 employees            7500.5
# 178      51 to 200 employees             125.5
# 179  5001 to 10000 employees            7500.5
# 180    501 to 1000 employees             750.5
# 181         10000+ employees  10000+ employees
# 182     201 to 500 employees             350.5
# 183                  Unknown           Unknown
# 184    501 to 1000 employees             750.5
# 185      51 to 200 employees             125.5
# 186         10000+ employees  10000+ employees
# 187                  Unknown           Unknown
# 188         10000+ employees  10000+ employees
# 189      51 to 200 employees             125.5
# 190  5001 to 10000 employees            7500.5
# 191     201 to 500 employees             350.5
# 192    501 to 1000 employees             750.5
# 193      51 to 200 employees             125.5
# 194      51 to 200 employees             125.5
# 195    501 to 1000 employees             750.5
# 196      51 to 200 employees             125.5
# 197         10000+ employees  10000+ employees
# 198   1001 to 5000 employees            3000.5
# 199    501 to 1000 employees             750.5
# 200   1001 to 5000 employees            3000.5
# 201     201 to 500 employees             350.5
# 202        1 to 50 employees              25.5
# 203     201 to 500 employees             350.5
# 204  5001 to 10000 employees            7500.5
# 205        1 to 50 employees              25.5
# 206     201 to 500 employees             350.5
# 207   1001 to 5000 employees            3000.5
# 208         10000+ employees  10000+ employees
# 209    501 to 1000 employees             750.5
# 210    501 to 1000 employees             750.5
# 211  5001 to 10000 employees            7500.5
# 212    501 to 1000 employees             750.5
# 213   1001 to 5000 employees            3000.5
# 214      51 to 200 employees             125.5
# 215      51 to 200 employees             125.5
# 216     201 to 500 employees             350.5
# 217    501 to 1000 employees             750.5
# 218      51 to 200 employees             125.5
# 219   1001 to 5000 employees            3000.5
# 220      51 to 200 employees             125.5
# 221    501 to 1000 employees             750.5
# 222  5001 to 10000 employees            7500.5
# 223        1 to 50 employees              25.5
# 224    501 to 1000 employees             750.5
# 225  5001 to 10000 employees            7500.5
# 226   1001 to 5000 employees            3000.5
# 227   1001 to 5000 employees            3000.5
# 228         10000+ employees  10000+ employees
# 229        1 to 50 employees              25.5
# 230      51 to 200 employees             125.5
# 231        1 to 50 employees              25.5
# 232      51 to 200 employees             125.5
# 233   1001 to 5000 employees            3000.5
# 234     201 to 500 employees             350.5
# 235     201 to 500 employees             350.5
# 236        1 to 50 employees              25.5
# 237         10000+ employees  10000+ employees
# 238         10000+ employees  10000+ employees
# 239      51 to 200 employees             125.5
# 240        1 to 50 employees              25.5
# 241     201 to 500 employees             350.5
# 242  5001 to 10000 employees            7500.5
# 243        1 to 50 employees              25.5
# 244         10000+ employees  10000+ employees
# 245   1001 to 5000 employees            3000.5
# 246     201 to 500 employees             350.5
# 247     201 to 500 employees             350.5
# 248         10000+ employees  10000+ employees
# 249     201 to 500 employees             350.5
# 250                  Unknown           Unknown
# 251      51 to 200 employees             125.5
# 252    501 to 1000 employees             750.5
# 253                  Unknown           Unknown
# 254   1001 to 5000 employees            3000.5
# 255   1001 to 5000 employees            3000.5
# 256   1001 to 5000 employees            3000.5
# 257   1001 to 5000 employees            3000.5
# 258   1001 to 5000 employees            3000.5
# 259     201 to 500 employees             350.5
# 260         10000+ employees  10000+ employees
# 261        1 to 50 employees              25.5
# 262      51 to 200 employees             125.5
# 263   1001 to 5000 employees            3000.5
# 264         10000+ employees  10000+ employees
# 265      51 to 200 employees             125.5
# 266                  Unknown           Unknown
# 267   1001 to 5000 employees            3000.5
# 268     201 to 500 employees             350.5
# 269         10000+ employees  10000+ employees
# 270     201 to 500 employees             350.5
# 271         10000+ employees  10000+ employees
# 272   1001 to 5000 employees            3000.5
# 273      51 to 200 employees             125.5
# 274                  Unknown           Unknown
# 275    501 to 1000 employees             750.5
# 276        1 to 50 employees              25.5
# 277                  Unknown           Unknown
# 278         10000+ employees  10000+ employees
# 279         10000+ employees  10000+ employees
# 280      51 to 200 employees             125.5
# 281      51 to 200 employees             125.5
# 282      51 to 200 employees             125.5
# 283     201 to 500 employees             350.5
# 284         10000+ employees  10000+ employees
# 285   1001 to 5000 employees            3000.5
# 286    501 to 1000 employees             750.5
# 287         10000+ employees  10000+ employees
# 288        1 to 50 employees              25.5
# 289        1 to 50 employees              25.5
# 290   1001 to 5000 employees            3000.5
# 291         10000+ employees  10000+ employees
# 292         10000+ employees  10000+ employees
# 293    501 to 1000 employees             750.5
# 294    501 to 1000 employees             750.5
# 295      51 to 200 employees             125.5
# 296      51 to 200 employees             125.5
# 297     201 to 500 employees             350.5
# 298        1 to 50 employees              25.5
# 299                  Unknown           Unknown
# 300  5001 to 10000 employees            7500.5
# 301      51 to 200 employees             125.5
# 302  5001 to 10000 employees            7500.5
# 303     201 to 500 employees             350.5
# 304     201 to 500 employees             350.5
# 305     201 to 500 employees             350.5
# 306   1001 to 5000 employees            3000.5
# 307      51 to 200 employees             125.5
# 308      51 to 200 employees             125.5
# 309    501 to 1000 employees             750.5
# 310        1 to 50 employees              25.5
# 311      51 to 200 employees             125.5
# 312         10000+ employees  10000+ employees
# 313        1 to 50 employees              25.5
# 314   1001 to 5000 employees            3000.5
# 315    501 to 1000 employees             750.5
# 316      51 to 200 employees             125.5
# 317   1001 to 5000 employees            3000.5
# 318     201 to 500 employees             350.5
# 319      51 to 200 employees             125.5
# 320      51 to 200 employees             125.5
# 321    501 to 1000 employees             750.5
# 322   1001 to 5000 employees            3000.5
# 323    501 to 1000 employees             750.5
# 324        1 to 50 employees              25.5
# 325         10000+ employees  10000+ employees
# 326    501 to 1000 employees             750.5
# 327         10000+ employees  10000+ employees
# 328    501 to 1000 employees             750.5
# 329        1 to 50 employees              25.5
# 330    501 to 1000 employees             750.5
# 331     201 to 500 employees             350.5
# 332        1 to 50 employees              25.5
# 333      51 to 200 employees             125.5
# 334    501 to 1000 employees             750.5
# 335      51 to 200 employees             125.5
# 336   1001 to 5000 employees            3000.5
# 337   1001 to 5000 employees            3000.5
# 338         10000+ employees  10000+ employees
# 339        1 to 50 employees              25.5
# 340        1 to 50 employees              25.5
# 341     201 to 500 employees             350.5
# 342                       -1                -1
# 343  5001 to 10000 employees            7500.5
# 344        1 to 50 employees              25.5
# 345      51 to 200 employees             125.5
# 346        1 to 50 employees              25.5
# 347      51 to 200 employees             125.5
# 348                       -1                -1
# 349                       -1                -1
# 350                       -1                -1
# 351                       -1                -1
# 352                       -1                -1
# 353                       -1                -1
# 354  5001 to 10000 employees            7500.5
# 355     201 to 500 employees             350.5
# 356         10000+ employees  10000+ employees
# 357  5001 to 10000 employees            7500.5
# 358   1001 to 5000 employees            3000.5
# 359      51 to 200 employees             125.5
# 360     201 to 500 employees             350.5
# 361         10000+ employees  10000+ employees
# 362      51 to 200 employees             125.5
# 363         10000+ employees  10000+ employees
# 364        1 to 50 employees              25.5
# 365     201 to 500 employees             350.5
# 366   1001 to 5000 employees            3000.5
# 367        1 to 50 employees              25.5
# 368     201 to 500 employees             350.5
# 369   1001 to 5000 employees            3000.5
# 370  5001 to 10000 employees            7500.5
# 371    501 to 1000 employees             750.5
# 372  5001 to 10000 employees            7500.5
# 373        1 to 50 employees              25.5
# 374         10000+ employees  10000+ employees
# 375   1001 to 5000 employees            3000.5
# 376     201 to 500 employees             350.5
# 377      51 to 200 employees             125.5
# 378  5001 to 10000 employees            7500.5
# 379                       -1                -1
# 380                       -1                -1
# 381    501 to 1000 employees             750.5
# 382  5001 to 10000 employees            7500.5
# 383   1001 to 5000 employees            3000.5
# 384      51 to 200 employees             125.5
# 385    501 to 1000 employees             750.5
# 386         10000+ employees  10000+ employees
# 387    501 to 1000 employees             750.5
# 388  5001 to 10000 employees            7500.5
# 389   1001 to 5000 employees            3000.5
# 390     201 to 500 employees             350.5
# 391    501 to 1000 employees             750.5
# 392         10000+ employees  10000+ employees
# 393   1001 to 5000 employees            3000.5
# 394     201 to 500 employees             350.5
# 395  5001 to 10000 employees            7500.5
# 396      51 to 200 employees             125.5
# 397   1001 to 5000 employees            3000.5
# 398   1001 to 5000 employees            3000.5
# 399      51 to 200 employees             125.5
# 400                  Unknown           Unknown
# 401     201 to 500 employees             350.5
# 402        1 to 50 employees              25.5
# 403        1 to 50 employees              25.5
# 404        1 to 50 employees              25.5
# 405        1 to 50 employees              25.5
# 406      51 to 200 employees             125.5
# 407     201 to 500 employees             350.5
# 408         10000+ employees  10000+ employees
# 409  5001 to 10000 employees            7500.5
# 410     201 to 500 employees             350.5
# 411         10000+ employees  10000+ employees
# 412    501 to 1000 employees             750.5
# 413        1 to 50 employees              25.5
# 414   1001 to 5000 employees            3000.5
# 415                  Unknown           Unknown
# 416        1 to 50 employees              25.5
# 417      51 to 200 employees             125.5
# 418    501 to 1000 employees             750.5
# 419     201 to 500 employees             350.5
# 420      51 to 200 employees             125.5
# 421                  Unknown           Unknown
# 422        1 to 50 employees              25.5
# 423      51 to 200 employees             125.5
# 424      51 to 200 employees             125.5
# 425         10000+ employees  10000+ employees
# 426        1 to 50 employees              25.5
# 427        1 to 50 employees              25.5
# 428      51 to 200 employees             125.5
# 429        1 to 50 employees              25.5
# 430     201 to 500 employees             350.5
# 431        1 to 50 employees              25.5
# 432        1 to 50 employees              25.5
# 433         10000+ employees  10000+ employees
# 434   1001 to 5000 employees            3000.5
# 435                  Unknown           Unknown
# 436    501 to 1000 employees             750.5
# 437     201 to 500 employees             350.5
# 438  5001 to 10000 employees            7500.5
# 439         10000+ employees  10000+ employees
# 440         10000+ employees  10000+ employees
# 441   1001 to 5000 employees            3000.5
# 442   1001 to 5000 employees            3000.5
# 443         10000+ employees  10000+ employees
# 444      51 to 200 employees             125.5
# 445        1 to 50 employees              25.5
# 446         10000+ employees  10000+ employees
# 447    501 to 1000 employees             750.5
# 448        1 to 50 employees              25.5
# 449    501 to 1000 employees             750.5
# 450                       -1                -1
# 451   1001 to 5000 employees            3000.5
# 452    501 to 1000 employees             750.5
# 453        1 to 50 employees              25.5
# 454     201 to 500 employees             350.5
# 455      51 to 200 employees             125.5
# 456        1 to 50 employees              25.5
# 457      51 to 200 employees             125.5
# 458    501 to 1000 employees             750.5
# 459   1001 to 5000 employees            3000.5
# 460      51 to 200 employees             125.5
# 461   1001 to 5000 employees            3000.5
# 462    501 to 1000 employees             750.5
# 463         10000+ employees  10000+ employees
# 464        1 to 50 employees              25.5
# 465   1001 to 5000 employees            3000.5
# 466  5001 to 10000 employees            7500.5
# 467        1 to 50 employees              25.5
# 468      51 to 200 employees             125.5
# 469     201 to 500 employees             350.5
# 470     201 to 500 employees             350.5
# 471     201 to 500 employees             350.5
# 472   1001 to 5000 employees            3000.5
# 473   1001 to 5000 employees            3000.5
# 474     201 to 500 employees             350.5
# 475  5001 to 10000 employees            7500.5
# 476        1 to 50 employees              25.5
# 477        1 to 50 employees              25.5
# 478    501 to 1000 employees             750.5
# 479   1001 to 5000 employees            3000.5
# 480        1 to 50 employees              25.5
# 481        1 to 50 employees              25.5
# 482      51 to 200 employees             125.5
# 483     201 to 500 employees             350.5
# 484         10000+ employees  10000+ employees
# 485        1 to 50 employees              25.5
# 486                       -1                -1
# 487                       -1                -1
# 488                       -1                -1
# 489                       -1                -1
# 490                       -1                -1
# 491                       -1                -1
# 492        1 to 50 employees              25.5
# 493      51 to 200 employees             125.5
# 494        1 to 50 employees              25.5
# 495        1 to 50 employees              25.5
# 496      51 to 200 employees             125.5
# 497      51 to 200 employees             125.5
# 498        1 to 50 employees              25.5
# 499         10000+ employees  10000+ employees
# 500         10000+ employees  10000+ employees
# 501     201 to 500 employees             350.5
# 502        1 to 50 employees              25.5
# 503  5001 to 10000 employees            7500.5
# 504                  Unknown           Unknown
# 505  5001 to 10000 employees            7500.5
# 506    501 to 1000 employees             750.5
# 507   1001 to 5000 employees            3000.5
# 508      51 to 200 employees             125.5
# 509     201 to 500 employees             350.5
# 510                       -1                -1
# 511      51 to 200 employees             125.5
# 512      51 to 200 employees             125.5
# 513    501 to 1000 employees             750.5
# 514   1001 to 5000 employees            3000.5
# 515                  Unknown           Unknown
# 516        1 to 50 employees              25.5
# 517     201 to 500 employees             350.5
# 518   1001 to 5000 employees            3000.5
# 519      51 to 200 employees             125.5
# 520        1 to 50 employees              25.5
# 521      51 to 200 employees             125.5
# 522        1 to 50 employees              25.5
# 523        1 to 50 employees              25.5
# 524    501 to 1000 employees             750.5
# 525      51 to 200 employees             125.5
# 526         10000+ employees  10000+ employees
# 527         10000+ employees  10000+ employees
# 528     201 to 500 employees             350.5
# 529    501 to 1000 employees             750.5
# 530     201 to 500 employees             350.5
# 531   1001 to 5000 employees            3000.5
# 532  5001 to 10000 employees            7500.5
# 533   1001 to 5000 employees            3000.5
# 534    501 to 1000 employees             750.5
# 535  5001 to 10000 employees            7500.5
# 536    501 to 1000 employees             750.5
# 537      51 to 200 employees             125.5
# 538     201 to 500 employees             350.5
# 539         10000+ employees  10000+ employees
# 540     201 to 500 employees             350.5
# 541      51 to 200 employees             125.5
# 542    501 to 1000 employees             750.5
# 543   1001 to 5000 employees            3000.5
# 544   1001 to 5000 employees            3000.5
# 545  5001 to 10000 employees            7500.5
# 546                       -1                -1
# 547    501 to 1000 employees             750.5
# 548    501 to 1000 employees             750.5
# 549      51 to 200 employees             125.5
# 550    501 to 1000 employees             750.5
# 551      51 to 200 employees             125.5
# 552   1001 to 5000 employees            3000.5
# 553   1001 to 5000 employees            3000.5
# 554  5001 to 10000 employees            7500.5
# 555    501 to 1000 employees             750.5
# 556   1001 to 5000 employees            3000.5
# 557      51 to 200 employees             125.5
# 558        1 to 50 employees              25.5
# 559                  Unknown           Unknown
# 560  5001 to 10000 employees            7500.5
# 561         10000+ employees  10000+ employees
# 562      51 to 200 employees             125.5
# 563    501 to 1000 employees             750.5
# 564  5001 to 10000 employees            7500.5
# 565   1001 to 5000 employees            3000.5
# 566     201 to 500 employees             350.5
# 567    501 to 1000 employees             750.5
# 568    501 to 1000 employees             750.5
# 569         10000+ employees  10000+ employees
# 570      51 to 200 employees             125.5
# 571      51 to 200 employees             125.5
# 572         10000+ employees  10000+ employees
# 573  5001 to 10000 employees            7500.5
# 574  5001 to 10000 employees            7500.5
# 575      51 to 200 employees             125.5
# 576      51 to 200 employees             125.5
# 577      51 to 200 employees             125.5
# 578   1001 to 5000 employees            3000.5
# 579      51 to 200 employees             125.5
# 580         10000+ employees  10000+ employees
# 581  5001 to 10000 employees            7500.5
# 582         10000+ employees  10000+ employees
# 583  5001 to 10000 employees            7500.5
# 584   1001 to 5000 employees            3000.5
# 585         10000+ employees  10000+ employees
# 586                  Unknown           Unknown
# 587     201 to 500 employees             350.5
# 588      51 to 200 employees             125.5
# 589        1 to 50 employees              25.5
# 590         10000+ employees  10000+ employees
# 591     201 to 500 employees             350.5
# 592  5001 to 10000 employees            7500.5
# 593        1 to 50 employees              25.5
# 594        1 to 50 employees              25.5
# 595        1 to 50 employees              25.5
# 596      51 to 200 employees             125.5
# 597         10000+ employees  10000+ employees
# 598        1 to 50 employees              25.5
# 599      51 to 200 employees             125.5
# 600        1 to 50 employees              25.5
# 601  5001 to 10000 employees            7500.5
# 602                       -1                -1
# 603         10000+ employees  10000+ employees
# 604                  Unknown           Unknown
# 605   1001 to 5000 employees            3000.5
# 606         10000+ employees  10000+ employees
# 607      51 to 200 employees             125.5
# 608      51 to 200 employees             125.5
# 609  5001 to 10000 employees            7500.5
# 610        1 to 50 employees              25.5
# 611    501 to 1000 employees             750.5
# 612        1 to 50 employees              25.5
# 613      51 to 200 employees             125.5
# 614      51 to 200 employees             125.5
# 615   1001 to 5000 employees            3000.5
# 616        1 to 50 employees              25.5
# 617   1001 to 5000 employees            3000.5
# 618      51 to 200 employees             125.5
# 619     201 to 500 employees             350.5
# 620         10000+ employees  10000+ employees
# 621      51 to 200 employees             125.5
# 622  5001 to 10000 employees            7500.5
# 623      51 to 200 employees             125.5
# 624        1 to 50 employees              25.5
# 625        1 to 50 employees              25.5
# 626  5001 to 10000 employees            7500.5
# 627      51 to 200 employees             125.5
# 628        1 to 50 employees              25.5
# 629      51 to 200 employees             125.5
# 630     201 to 500 employees             350.5
# 631   1001 to 5000 employees            3000.5
# 632         10000+ employees  10000+ employees
# 633         10000+ employees  10000+ employees
# 634  5001 to 10000 employees            7500.5
# 635   1001 to 5000 employees            3000.5
# 636      51 to 200 employees             125.5
# 637     201 to 500 employees             350.5
# 638                       -1                -1
# 639         10000+ employees  10000+ employees
# 640      51 to 200 employees             125.5
# 641  5001 to 10000 employees            7500.5
# 642      51 to 200 employees             125.5
# 643      51 to 200 employees             125.5
# 644                       -1                -1
# 645                       -1                -1
# 646      51 to 200 employees             125.5
# 647         10000+ employees  10000+ employees
# 648                       -1                -1
# 649         10000+ employees  10000+ employees
# 650      51 to 200 employees             125.5
# 651    501 to 1000 employees             750.5
# 652        1 to 50 employees              25.5
# 653     201 to 500 employees             350.5
# 654   1001 to 5000 employees            3000.5
# 655   1001 to 5000 employees            3000.5
# 656                       -1                -1
# 657                       -1                -1
# 658        1 to 50 employees              25.5
# 659   1001 to 5000 employees            3000.5
